# %%
import yfinance as yf
#yf.pdr_override()
#web.get_data_yahoo('2330.TW')
data = yf.download('2330.TW', start='2023-01-01', end='2024-10-27')
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                        Adj Close   Close    High     Low    Open  \
# Ticker                         2330.TW 2330.TW 2330.TW 2330.TW 2330.TW
# Date
# 2023-01-03 00:00:00+00:00   437.941589   453.0   453.5   443.0   446.0
# 2023-01-04 00:00:00+00:00   434.557953   449.5   455.0   448.5   449.5
# 2023-01-05 00:00:00+00:00   443.258789   458.5   459.5   455.0   459.0
# 2023-01-06 00:00:00+00:00   443.258789   458.5   459.5   455.0   455.0
# 2023-01-09 00:00:00+00:00   465.010864   481.0   481.0   467.5   468.0
# ...                                ...     ...     ...     ...     ...
# 2024-10-21 00:00:00+00:00  1085.000000  1085.0  1095.0  1080.0  1090.0
# 2024-10-22 00:00:00+00:00  1075.000000  1075.0  1075.0  1060.0  1065.0
# 2024-10-23 00:00:00+00:00  1060.000000  1060.0  1070.0  1055.0  1060.0
# 2024-10-24 00:00:00+00:00  1060.000000  1060.0  1075.0  1055.0  1070.0
# ...

# %%
#台灣大盤[^TWII]
#web.get_data_yahoo('^TWII')
data1 = yf.download('^TWII', start='2023-01-01', end='2024-10-27')
data1
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                         Adj Close         Close          High  \
# Ticker                            ^TWII         ^TWII         ^TWII
# Date
# 2023-01-03 00:00:00+00:00  14224.120117  14224.120117  14237.940430
# 2023-01-04 00:00:00+00:00  14199.129883  14199.129883  14257.450195
# 2023-01-05 00:00:00+00:00  14301.049805  14301.049805  14357.599609
# 2023-01-06 00:00:00+00:00  14373.339844  14373.339844  14384.919922
# 2023-01-09 00:00:00+00:00  14752.209961  14752.209961  14752.209961
# ...                                 ...           ...           ...
# 2024-10-21 00:00:00+00:00  23542.529297  23542.529297  23678.509766
# 2024-10-22 00:00:00+00:00  23535.429688  23535.429688  23535.429688
# 2024-10-23 00:00:00+00:00  23334.759766  23334.759766  23486.449219
# 2024-10-24 00:00:00+00:00  23192.519531  23192.519531  23446.640625
# 2024-10-25 00:00:00+00:00  23348.449219  23348.449219  23388.529297
#
# ...

# %%
taiwan = yf.download('^TWII', start='2023-01-01', end='2024-10-27')
taiwan
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                         Adj Close         Close          High  \
# Ticker                            ^TWII         ^TWII         ^TWII
# Date
# 2023-01-03 00:00:00+00:00  14224.120117  14224.120117  14237.940430
# 2023-01-04 00:00:00+00:00  14199.129883  14199.129883  14257.450195
# 2023-01-05 00:00:00+00:00  14301.049805  14301.049805  14357.599609
# 2023-01-06 00:00:00+00:00  14373.339844  14373.339844  14384.919922
# 2023-01-09 00:00:00+00:00  14752.209961  14752.209961  14752.209961
# ...                                 ...           ...           ...
# 2024-10-21 00:00:00+00:00  23542.529297  23542.529297  23678.509766
# 2024-10-22 00:00:00+00:00  23535.429688  23535.429688  23535.429688
# 2024-10-23 00:00:00+00:00  23334.759766  23334.759766  23486.449219
# 2024-10-24 00:00:00+00:00  23192.519531  23192.519531  23446.640625
# 2024-10-25 00:00:00+00:00  23348.449219  23348.449219  23388.529297
#
# ...

# %%
from datetime import datetime
#使用index比較符合我們的需求
all_data = taiwan.to_dict(orient='index')
#先取出key,再一筆一筆取出資料
for key,value in all_data.items():
    print(key)
    print(type(key))
    print(value)
    print("=========")
